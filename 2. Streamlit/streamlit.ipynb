# %% [markdown]
# #### Introduction to Stramlit
#
# Streamlit is an open-source app freamework for Machine Learning and Data Science projects. It allows you to create beautiful web applications for your machine learning and data science projects with simple pyhton scripts.
